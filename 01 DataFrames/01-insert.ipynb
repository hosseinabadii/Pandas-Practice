# %%
import pandas as pd

# %%
nba = pd.read_csv("../data/nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.insert(loc=5, column="Sport", value="basketball")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age       Sport Height  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0  basketball    6-2
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0  basketball    6-6
# 2   John Holland  Boston Celtics    30.0       SG  27.0  basketball    6-5
#
#    Weight            College     Salary
# 0   180.0              Texas  7730337.0
# 1   235.0          Marquette  6796117.0
# 2   205.0  Boston University        NaN

# %%
nba.insert(loc=1, column="League", value="leage value")
nba.head(3)
# Out:
#             Name       League            Team  Number Position   Age  \
# 0  Avery Bradley  leage value  Boston Celtics     0.0       PG  25.0
# 1    Jae Crowder  leage value  Boston Celtics    99.0       SF  25.0
# 2   John Holland  leage value  Boston Celtics    30.0       SG  27.0
#
#         Sport Height  Weight            College     Salary
# 0  basketball    6-2   180.0              Texas  7730337.0
# 1  basketball    6-6   235.0          Marquette  6796117.0
# 2  basketball    6-5   205.0  Boston University        NaN
