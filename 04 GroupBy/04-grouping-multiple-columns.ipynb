# %%
import pandas as pd
df = pd.read_csv("../data/fortune1000.csv", index_col="Rank")
sectors = df.groupby(by=["Sector", "Industry"])
df.head(3)
# Out:
#           Company      Sector                     Industry         Location  \
# Rank
# 1         Walmart   Retailing        General Merchandisers  Bentonville, AR
# 2     Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 3           Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#       Revenue  Profits  Employees
# Rank
# 1      482130    14694    2300000
# 2      246204    16150      75600
# 3      233715    53394     110000

# %%
sectors.size().head(20)
# Out:
# Sector                      Industry
# Aerospace & Defense         Aerospace and Defense               20
# Apparel                     Apparel                             15
# Business Services           Advertising, marketing               2
#                             Diversified Outsourcing Services    14
#                             Education                            3
#                             Financial Data Services             19
#                             Miscellaneous                        3
#                             Temporary Help                       5
#                             Waste Management                     5
# Chemicals                   Chemicals                           30
# Energy                      Energy                              14
#                             Mining, Crude-Oil Production        28
#                             Miscellaneous                        1
# ...

# %%
sectors.indices
# Out:
# {('Aerospace & Defense',
#   'Aerospace and Defense'): array([ 23,  44,  59,  87, 117, 119, 208, 244, 281, 377, 388, 489, 559,
#         604, 784, 787, 835, 902, 957, 986]),
#  ('Apparel',
#   'Apparel'): array([ 90, 230, 339, 353, 447, 546, 574, 596, 682, 694, 725, 793, 876,
#         881, 916]),
#  ('Business Services', 'Advertising, marketing'): array([185, 354]),
#  ('Business Services',
#   'Diversified Outsourcing Services'): array([198, 247, 484, 544, 625, 634, 713, 728, 743, 782, 802, 815, 818,
#         868]),
#  ('Business Services', 'Education'): array([736, 819, 992]),
#  ('Business Services',
#   'Financial Data Services'): array([203, 248, 293, 306, 391, 403, 467, 480, 491, 651, 693, 766, 775,
#         776, 791, 795, 800, 885, 951]),
#  ('Business Services', 'Miscellaneous'): array([439, 733, 869]),
#  ('Business Services', 'Temporary Help'): array([143, 466, 502, 790, 950]),
#  ('Business Services', 'Waste Management'): array([220, 311, 676, 734, 938]),
# ...

# %%
sectors.get_group(("Energy", "Pipelines"))
# Out:
#                            Company  Sector   Industry           Location  \
# Rank
# 65          Energy Transfer Equity  Energy  Pipelines         Dallas, TX
# 104   Enterprise Products Partners  Energy  Pipelines        Houston, TX
# 121             Plains GP Holdings  Energy  Pipelines        Houston, TX
# 198                  Kinder Morgan  Energy  Pipelines        Houston, TX
# 348                          Oneok  Energy  Pipelines          Tulsa, OK
# 387                Targa Resources  Energy  Pipelines        Houston, TX
# 493                 Spectra Energy  Energy  Pipelines        Houston, TX
# 656               Buckeye Partners  Energy  Pipelines        Houston, TX
# 859      Enable Midstream Partners  Energy  Pipelines  Oklahoma City, OK
# 908                 Genesis Energy  Energy  Pipelines        Houston, TX
# 924    Magellan Midstream Partners  Energy  Pipelines          Tulsa, OK
# 948                  NuStar Energy  Energy  Pipelines    San Antonio, TX
#
# ...

# %%
sectors.get_group(("Energy", "Pipelines"))["Profits"].sum()
# Out:
# 5814

# %%
sectors.sum(numeric_only=True).loc[(("Energy", "Pipelines")), "Profits"]
# Out:
# 5814

# %%
df.query("Sector == 'Energy' and Industry == 'Pipelines'")["Profits"].sum()
# Out:
# 5814

# %%
sectors.sum(numeric_only=True)
# Out:
#                                                                    Revenue  \
# Sector              Industry
# Aerospace & Defense Aerospace and Defense                           357940
# Apparel             Apparel                                          95968
# Business Services   Advertising, marketing                           22748
#                     Diversified Outsourcing Services                 64829
#                     Education                                         7485
# ...                                                                    ...
# Transportation      Trucking, Truck Leasing                          35950
# Wholesalers         Miscellaneous                                     8982
#                     Wholesalers: Diversified                        176138
#                     Wholesalers: Electronics and Office Equipment   147906
#                     Wholesalers: Food and Grocery                   111774
#
# ...
